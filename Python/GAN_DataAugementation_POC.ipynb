# %%
import pandas as pd

# %%
dataset = pd.read_csv("../DataSets/poverty_A.gz")

# %%
dataset.head()
# Out:
#    cat_0  cat_1  cat_2  cat_3  cat_4  cat_5  num_6  cat_7  cat_8  cat_9  ...  \
# 0  XJsPz  mOlYV  UFoKR  SSvEP  onRNG  YXCNt    4.0  oArAw  kpkiH  fohru  ...
# 1  XJsPz  mOlYV  axSTs  CXizI  onRNG  YXCNt    4.0  ccbZA  HgfUG  fohru  ...
# 2  TRFeI  mOlYV  axSTs  CXizI  NDnCs  YXCNt    4.0  fOUHD  HgfUG  oEref  ...
# 3  XJsPz  yAyAe  FRcdT  CXizI  onRNG  YXCNt    NaN  fOUHD  HgfUG  fohru  ...
# 4  XJsPz  mOlYV  UFoKR  HIvIU  onRNG  YXCNt    4.0  oArAw  kpkiH  fohru  ...
#
#   cat_31 num_32 cat_33 cat_34 cat_35 cat_36 cat_37 cat_38 cat_39 target
# 0  yOwsR    181  QQdHS  uEstx  Hikoa  zQvdC  xUYIC  juMSt  dSJoN   True
# 1  yOwsR    141  QQdHS  uEstx  Hikoa  zQvdC  xUYIC  juMSt  JTCKs   True
# 2  yOwsR     41  QQdHS  gCSRj  Hikoa  zQvdC  rkLqZ  juMSt  JTCKs   True
# 3  yOwsR     16  QQdHS  uEstx  Hikoa  zQvdC  jVHyH  GtHel  JTCKs   True
# 4  yOwsR    381  QQdHS  uEstx  Hikoa  zQvdC  xUYIC  juMSt  UaIsy  False
#
# [5 rows x 41 columns]
